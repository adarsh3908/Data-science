# %% [markdown]
# EDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r"C:\Users\ASUS\Downloads\data+science\data science\drive-download-20211129T055036Z-001 (1)\covid19_Confirmed_dataset.csv")
dataset.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
dataset.shape
# Out:
# (266, 104)

# %%
df = dataset.drop(["Lat", "Long"], axis=1)
df.head()
# Out:
#   Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan        0        0        0        0        0
# 1            NaN        Albania        0        0        0        0        0
# 2            NaN        Algeria        0        0        0        0        0
# 3            NaN        Andorra        0        0        0        0        0
# 4            NaN         Angola        0        0        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
corona_dataset_aggregated = dataset.groupby("Country/Region").sum()
corona_dataset_aggregated.head()
# Out:
#                Province/State      Lat     Long  1/22/20  1/23/20  1/24/20  \
# Country/Region
# Afghanistan                 0  33.0000  65.0000        0        0        0
# Albania                     0  41.1533  20.1683        0        0        0
# Algeria                     0  28.0339   1.6596        0        0        0
# Andorra                     0  42.5063   1.5218        0        0        0
# Angola                      0 -11.2027  17.8739        0        0        0
#
#                 1/25/20  1/26/20  1/27/20  1/28/20  ...  4/21/20  4/22/20  \
# Country/Region                                      ...
# Afghanistan           0        0        0        0  ...     1092     1176
# Albania               0        0        0        0  ...      609      634
# Algeria               0        0        0        0  ...     2811     2910
# Andorra               0        0        0        0  ...      717      723
# ...

# %%
dataset = pd.read_csv("C:\\Users\\ASUS\\Downloads\\data+science\\data science\\drive-download-20211129T055036Z-001 (1)\\covid19_Confirmed_dataset.csv", encoding='utf-8')
china_data = dataset[dataset["Province/State"].str.contains("Hubei|Beijing|Shanghai|Guangdong", na=False)]

# %%
print(dataset.head())
print(dataset.columns.tolist())  # Check actual column names
dataset.columns = dataset.columns.str.strip()
dataset["Country/Region"]
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
china_data = dataset[dataset["Country/Region"] == "China"]
china_aggregated = china_data.iloc[:, 4:].sum()  # Sum all provinces if needed
china_aggregated.plot(label="China")
india_data = dataset[dataset["Country/Region"] == "India"]
india_aggregated = india_data.iloc[:, 4:].sum()  # Sum all provinces if needed
india_aggregated.plot(label="India")
spain_data = dataset[dataset["Country/Region"] == "Spain"]
spain_aggregated = spain_data.iloc[:, 4:].sum()  # Sum all provinces if needed
spain_aggregated.plot(label="Spain")
plt.legend()

# %%
china_data = dataset[dataset["Country/Region"] == "China"]
china_aggregated = china_data.iloc[:, 4:].sum()  # Sum all provinces if needed
china_aggregated.head(3).plot()
# Out:
# <Axes: >

# %%
china_data = corona_dataset_aggregated.loc["China"]
china_data_numeric = pd.to_numeric(china_data.iloc[4:], errors='coerce')
china_data_numeric.diff().plot()
# Out:
# <Axes: >

# %%
china_data_numeric.diff().max()
# Out:
# 15136.0

# %%
india_data = corona_dataset_aggregated.loc["India"]
india_data_numeric = pd.to_numeric(india_data.iloc[4:], errors='coerce')
india_data_numeric.diff().max()
# Out:
# 1893.0

# %%
spain_data = corona_dataset_aggregated.loc["Spain"]
spain_data_numeric = pd.to_numeric(spain_data.iloc[4:], errors='coerce')
spain_data_numeric.diff().max()
# Out:
# 9630.0

# %%
corona_dataset_aggregated
# Out:
#                    Province/State        Lat       Long  1/22/20  1/23/20  \
# Country/Region
# Afghanistan                     0  33.000000  65.000000        0        0
# Albania                         0  41.153300  20.168300        0        0
# Algeria                         0  28.033900   1.659600        0        0
# Andorra                         0  42.506300   1.521800        0        0
# Angola                          0 -11.202700  17.873900        0        0
# ...                           ...        ...        ...      ...      ...
# West Bank and Gaza              0  31.952200  35.233200        0        0
# Western Sahara                  0  24.215500 -12.885800        0        0
# Yemen                           0  15.552727  48.516388        0        0
# Zambia                          0 -15.416700  28.283300        0        0
# Zimbabwe                        0 -20.000000  30.000000        0        0
#
# ...

# %%
countries = list(corona_dataset_aggregated.index)
max_infection_rates = []
corona_dataset_aggregated = corona_dataset_aggregated.apply(pd.to_numeric, errors='coerce')
for c in countries:
    max_infection_rates.append(corona_dataset_aggregated.loc[c].diff().max())
corona_dataset_aggregated["Max_infection_rates"] = max_infection_rates

# %%
corona_dataset_aggregated
# Out:
#                     Province/State        Lat       Long  1/22/20  1/23/20  \
# Country/Region
# Afghanistan                    0.0  33.000000  65.000000        0        0
# Albania                        0.0  41.153300  20.168300        0        0
# Algeria                        0.0  28.033900   1.659600        0        0
# Andorra                        0.0  42.506300   1.521800        0        0
# Angola                         0.0 -11.202700  17.873900        0        0
# ...                            ...        ...        ...      ...      ...
# West Bank and Gaza             0.0  31.952200  35.233200        0        0
# Western Sahara                 0.0  24.215500 -12.885800        0        0
# Yemen                          0.0  15.552727  48.516388        0        0
# Zambia                         0.0 -15.416700  28.283300        0        0
# Zimbabwe                       0.0 -20.000000  30.000000        0        0
#
# ...

# %%
corona_data = pd.DataFrame(corona_dataset_aggregated["Max_infection_rates"])

# %%
corona_data
# Out:
#                     Max_infection_rates
# Country/Region
# Afghanistan                  232.000000
# Albania                       41.153300
# Algeria                      199.000000
# Andorra                       43.000000
# Angola                        29.076600
# ...                                 ...
# West Bank and Gaza            66.000000
# Western Sahara                24.215500
# Yemen                         32.963661
# Zambia                        43.700000
# Zimbabwe                      50.000000
#
# [187 rows x 1 columns]

# %%
happiness_report = pd.read_csv(r"C:\Users\ASUS\Downloads\data+science\data science\drive-download-20211129T055036Z-001 (1)\worldwide_happiness_report.csv")

# %%
happiness_report
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
useless_cols = ["Overall rank","Score","Generosity","Perceptions of corruption"]
happiness_report.drop(useless_cols, axis =1, inplace =True)

# %%
happiness_report.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %%
happiness_report.set_index("Country or region",inplace = True)
happiness_report.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
corona_data.shape
# Out:
# (187, 1)

# %%
happiness_report.shape
# Out:
# (156, 4)

# %%
data = corona_data.join(happiness_report, how = "inner")
data
# Out:
#              Max_infection_rates  GDP per capita  Social support  \
# Afghanistan           232.000000           0.350           0.517
# Albania                41.153300           0.947           0.848
# Algeria               199.000000           1.002           1.160
# Argentina             291.000000           1.092           1.432
# Armenia               134.000000           0.850           1.055
# ...                          ...             ...             ...
# Venezuela              66.589700           0.960           1.427
# Vietnam                92.000000           0.741           1.346
# Yemen                  32.963661           0.287           1.163
# Zambia                 43.700000           0.578           1.058
# Zimbabwe               50.000000           0.366           1.114
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# ...

# %%
data.corr()
# Out:
#                               Max_infection_rates  GDP per capita  \
# Max_infection_rates                      1.000000        0.251168
# GDP per capita                           0.251168        1.000000
# Social support                           0.194084        0.759468
# Healthy life expectancy                  0.291400        0.863062
# Freedom to make life choices             0.080686        0.394603
#
#                               Social support  Healthy life expectancy  \
# Max_infection_rates                 0.194084                 0.291400
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
#
#                               Freedom to make life choices
# Max_infection_rates                               0.080686
# ...

# %%
x= data["GDP per capita"]
y = data["Max_infection_rates"]
sns.scatterplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='GDP per capita', ylabel='Max_infection_rates'>

# %%
sns.regplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='GDP per capita', ylabel='Max_infection_rates'>

# %%
x= data["Social support"]
y = data["Max_infection_rates"]
sns.scatterplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='Social support', ylabel='Max_infection_rates'>

# %%
sns.regplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='Social support', ylabel='Max_infection_rates'>

# %%
x= data["Healthy life expectancy"]
y = data["Max_infection_rates"]
sns.scatterplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='Max_infection_rates'>

# %%
sns.regplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='Max_infection_rates'>

# %%
x= data["Freedom to make life choices"]
y = data["Max_infection_rates"]
sns.scatterplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='Max_infection_rates'>

# %%
sns.regplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='Max_infection_rates'>
